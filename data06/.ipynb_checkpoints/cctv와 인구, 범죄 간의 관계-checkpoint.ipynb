# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
from matplotlib import rc, font_manager
import matplotlib.font_manager as fm

fm._rebuild()
fm.get_fontconfig_fonts()

# 디렉토리 및 파일 이름에 맞추어 변경
# font_location = 'C:/Windows/Fonts/ARIALNI.TTF' #윈도우안에있는 폰트파일주소.
font_location = './NanumGothic.ttf'
font_name = fm.FontProperties(fname=font_location).get_name()
rc('font', family=font_name)

# %%
crime_seoul = pd.read_csv('./cctv_data_collect/crime_seoul_3.csv', encoding='euc-kr')
crime_seoul
# Out:
#       구별  살인 발생  강도 발생  강간 발생  절도 발생  폭력 발생
# 0     중구      2      3    105   1395   1355
# 1    종로구      3      6    115   1070   1278
# 2     중구      1      6     65   1153    869
# 3   서대문구      2      5    154   1812   2056
# 4    종로구      3      5     96   1114   1015
# 5    용산구      5     14    194   1557   2050
# 6    성북구      2      2     86    953   1194
# 7   동대문구      5     13    173   1981   2548
# 8    마포구      8     14    294   2555   2983
# 9   영등포구     14     22    295   2964   3572
# 10   성동구      4      9    126   1607   1612
# 11   동작구      5      9    285   1865   1910
# 12   광진구      4     14    240   3026   2625
# 13   은평구      2      2     70    819   1192
# 14   강북구      7     14    153   1434   2649
# 15   금천구      3      6    151   1567   2054
# 16   중랑구     13     11    187   2135   2847
# 17   강남구      3     15    300   2411   2465
# 18   관악구      9     12    320   2706   3298
# 19   강서구      7     13    262   2096   3207
# 20   강동구      4      6    156   2366   2712
# 21   성북구      3      3     64    832   1015
# 22   구로구      8     15    281   2335   3007
# 23   서초구      7      8    334   1982   1852
# 24   양천구      3      6    120   1890   2509
# 25   송파구     11     13    220   3239   3295
# 26   노원구     10      7    197   2193   2723
# 27   서초구      1      1     59    653    547
# 28   은평구      1      7     96   1095   1461
# 29   도봉구      3      9    102   1063   1487
# 30   강남구     10      6    149   1439   1819

# %%
crime_seoul['구별'].unique()
# Out:
# array(['중구', '종로구', '서대문구', '용산구', '성북구', '동대문구', '마포구', '영등포구', '성동구',
#        '동작구', '광진구', '은평구', '강북구', '금천구', '중랑구', '강남구', '관악구', '강서구',
#        '강동구', '구로구', '서초구', '양천구', '송파구', '노원구', '도봉구'], dtype=object)

# %%
len(crime_seoul['구별'].unique())
# Out:
# 25

# %%
crime_seoul.set_index('구별', inplace=True)
crime_seoul
# Out:
#       살인 발생  강도 발생  강간 발생  절도 발생  폭력 발생
# 구별
# 중구        2      3    105   1395   1355
# 종로구       3      6    115   1070   1278
# 중구        1      6     65   1153    869
# 서대문구      2      5    154   1812   2056
# 종로구       3      5     96   1114   1015
# 용산구       5     14    194   1557   2050
# 성북구       2      2     86    953   1194
# 동대문구      5     13    173   1981   2548
# 마포구       8     14    294   2555   2983
# 영등포구     14     22    295   2964   3572
# 성동구       4      9    126   1607   1612
# 동작구       5      9    285   1865   1910
# 광진구       4     14    240   3026   2625
# 은평구       2      2     70    819   1192
# 강북구       7     14    153   1434   2649
# 금천구       3      6    151   1567   2054
# 중랑구      13     11    187   2135   2847
# 강남구       3     15    300   2411   2465
# 관악구       9     12    320   2706   3298
# 강서구       7     13    262   2096   3207
# 강동구       4      6    156   2366   2712
# 성북구       3      3     64    832   1015
# 구로구       8     15    281   2335   3007
# 서초구       7      8    334   1982   1852
# 양천구       3      6    120   1890   2509
# 송파구      11     13    220   3239   3295
# 노원구      10      7    197   2193   2723
# 서초구       1      1     59    653    547
# 은평구       1      7     96   1095   1461
# 도봉구       3      9    102   1063   1487
# 강남구      10      6    149   1439   1819

# %%
crime_seoul.columns
# Out:
# Index(['살인 발생', '강도 발생', '강간 발생', '절도 발생', '폭력 발생'], dtype='object')

# %%
crime_seoul.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 31 entries, 중구 to 강남구
# Data columns (total 5 columns):
# 살인 발생    31 non-null int64
# 강도 발생    31 non-null int64
# 강간 발생    31 non-null int64
# 절도 발생    31 non-null int64
# 폭력 발생    31 non-null int64
# dtypes: int64(5)
# memory usage: 1.5+ KB

# %%
# 각각의 수치가 가장 높은 구는 어디일까?
crime_seoul.idxmax()
# Out:
# 살인 발생    영등포구
# 강도 발생    영등포구
# 강간 발생     서초구
# 절도 발생     송파구
# 폭력 발생    영등포구
# dtype: object

# %%
total_data = pd.read_csv('total_data_result3.csv', encoding='utf8')
total_data
# Out:
#     Unnamed: 0    구별    소계       최근증가율       인구수       한국인      외국인      고령자  \
# 0            0   강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0
# 1            1   강남구  2780  150.619195  570500.0  565550.0   4950.0  63167.0
# 2            2   강동구   773  166.490765  453233.0  449019.0   4214.0  54622.0
# 3            3   강북구   748  125.203252  330192.0  326686.0   3506.0  54813.0
# 4            4   강서구   884  134.793814  603772.0  597248.0   6524.0  72548.0
# 5            5   관악구  1496  149.290780  525515.0  507203.0  18312.0  68082.0
# 6            6   광진구   707   53.228621  372164.0  357211.0  14953.0  42214.0
# 7            7   구로구  1561   64.973730  447874.0  416487.0  31387.0  56833.0
# 8            8   금천구  1015  100.000000  255082.0  236353.0  18729.0  32970.0
# 9            9   노원구  1265  188.929889  569384.0  565565.0   3819.0  71941.0
# 10          10   도봉구   485  246.638655  348646.0  346629.0   2017.0  51312.0
# 11          11  동대문구  1294   74.766355  369496.0  354079.0  15417.0  54173.0
# 12          12   동작구  1091  139.338235  412520.0  400456.0  12064.0  56013.0
# 13          13   마포구   574  212.101911  389649.0  378566.0  11083.0  48765.0
# 14          14  서대문구   962   48.578199  327163.0  314982.0  12181.0  48161.0
# 15          15   서초구  1930   63.371266  450310.0  445994.0   4316.0  51733.0
# 16          17   성동구  1062   81.780822  311244.0  303380.0   7864.0  39997.0
# 17          19   성북구  1464   63.627354  461260.0  449773.0  11487.0  64692.0
# 18          21   양천구  2034   34.671731  479978.0  475949.0   4029.0  52975.0
# 19          23   용산구  1624   53.216374  244203.0  229456.0  14747.0  36231.0
# 20          25   은평구  1873   85.237258  494388.0  489943.0   4445.0  72334.0
inc = np.corrcoef(total_data['최근증가율'], total_data['범죄 발생'])
inc
# => cctv 최근증가율과 범죄 발생은 약간 음의 상관관계가 있다
# Out:
# array([[ 1.        , -0.18956881],
#        [-0.18956881,  1.        ]])

# %%
# 고령자비율과 범죄 발생의 상관관계
old_p = np.corrcoef(total_data['고령자비율'], total_data['범죄 발생'])
old_p
# => 고령자비율과 범죄 발생은 약간 음의 상관관계가 있다
# Out:
# array([[ 1.        , -0.56747453],
#        [-0.56747453,  1.        ]])

# %%
# 인구수와 범죄 발생의 상관관계
pop = np.corrcoef(total_data['인구수'], total_data['범죄 발생'])
pop
# 인구수와 범죄 발생은 양의 상관관계가 있다
# Out:
# array([[1.        , 0.54022888],
#        [0.54022888, 1.        ]])

# %%
murder_list = murder.tolist()
murder_list
# Out:
# [[1.0, -0.18664899976247973], [-0.1866489997624797, 1.0]]

# %%
murder_corr = murder_list[0][1]
murder_corr
# Out:
# -0.18664899976247973

# %%
inc_list = inc.tolist()
inc_list
# Out:
# [[0.9999999999999998, -0.189568806687079], [-0.18956880668707898, 1.0]]

# %%
inc_corr = inc_list[0][1]
inc_corr
# Out:
# -0.189568806687079

# %%
pop_list = pop.tolist()
pop_list
# Out:
# [[1.0, 0.5402288845959491], [0.5402288845959491, 1.0]]

# %%
pop_corr = pop_list[0][1]
pop_corr
# Out:
# 0.5402288845959491

# %%
old_p_list = old_p.tolist()
old_p_list
# Out:
# [[1.0, -0.5674745325528066], [-0.5674745325528066, 1.0]]

# %%
old_p_corr = old_p_list[0][1]
old_p_corr
# Out:
# -0.5674745325528066

# %%
corr_list = [murder_corr, inc_corr, pop_corr, old_p_corr]
corr_list
# Out:
# [-0.18664899976247973,
#  -0.189568806687079,
#  0.5402288845959491,
#  -0.5674745325528066]

# %%
x_data = ['murder_corr', 'inc_corr', 'pop_corr', 'old_p_corr']

# %%
fig = plt.plot(x_data, corr_list, 'ro')
plt.title('correlation')
# Out:
# Text(0.5,1,'correlation')

# %%
gwanag = total_data[total_data.index == '관악구']
gwanag
# Out:
#        소계      최근증가율       인구수       한국인      외국인      고령자     외국인비율  \
# 구별
# 관악구  1496  149.29078  525515.0  507203.0  18312.0  68082.0  3.484582
#
#          고령자비율  살인 발생  강도 발생  강간 발생  절도 발생  폭력 발생  범죄 발생
# 구별
# 관악구  12.955291      9     12    320   2706   3298   6345

# %%
fig = plt.plot(['범죄 발생', '외국인', '최근증가율', '고령자비율'], [6345, 18312.0, 149.29078, 12.955291])
plt.title('person count')
# Out:
# Text(0.5,1,'person count')

# %%
dr_corr = total_data.corr()

# %%
# heatmap
import seaborn as sns

# %%
cols = total_data.columns

# %%
sns.set(font_scale=1.5)

# %%
sns.heatmap(dr_corr.values,
            cbar = True,
            annot= True,
            square=True, 
            fmt = '.2f',
            xticklabels=cols,
            yticklabels=cols,
            annot_kws={"size": 5}
           )
