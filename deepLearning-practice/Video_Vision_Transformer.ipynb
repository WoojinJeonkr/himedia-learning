# %% [markdown]
# <a href="https://colab.research.google.com/github/WoojinJeonkr/DeepLearning/blob/main/Video_Vision_Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Video_Vision_Transformer

# %% [markdown]
# ## 01. medmnist 설치
# - 2D 및 3D 생물 의학 이미지 분류를 위한 대규모 경량 벤치마크

# %%
# !pip install -qq medmnist
# Out:
#      |████████████████████████████████| 87 kB 3.4 MB/s
#   Building wheel for fire (setup.py) ... done

# %% [markdown]
# ## 02. 라이브러리 불러오기 및 설정

# %%
# import library
import os
import io
import imageio
import medmnist
import ipywidgets
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

# %%
# setting
SEED = 42
os.environ["TF_CUDNN_DETERMINISTIC"] = "1"
keras.utils.set_random_seed(SEED)

# %% [markdown]
# ## 03. 하이퍼파라미터 설정

# %%
# 데이터
DATASET_NAME = "organmnist3d"
BATCH_SIZE = 32
AUTO = tf.data.AUTOTUNE
INPUT_SHAPE = (28, 28, 28, 1)
NUM_CLASSES = 11

# %%
# 옵티마이저 설정
LEARNING_RATE = 1e-4
WEIGHT_DECAY = 1e-5

# %%
# 반복횟수 정의
EPOCHS = 60

# 패치 설정
PATCH_SIZE = (8, 8, 8)
NUM_PATCHES = (INPUT_SHAPE[0] // PATCH_SIZE[0]) ** 2

LAYER_NORM_EPS = 1e-6
PROJECTION_DIM = 128
NUM_HEADS = 8
NUM_LAYERS = 8

# %% [markdown]
# ## 04. 데이터세트 다운로드

# %%
# 데이터세트 다운로드 및 훈련/검증/평가 데이터 분류
def download_and_prepare_dataset(data_info: dict):
    data_path = keras.utils.get_file(origin=data_info["url"], md5_hash=data_info["MD5"])

    with np.load(data_path) as data:
        # Get videos
        train_videos = data["train_images"]
        valid_videos = data["val_images"]
        test_videos = data["test_images"]

        # Get labels
        train_labels = data["train_labels"].flatten()
        valid_labels = data["val_labels"].flatten()
        test_labels = data["test_labels"].flatten()

    return (
        (train_videos, train_labels),
        (valid_videos, valid_labels),
        (test_videos, test_labels),
    )


# 데이터세트의 메타데이터 가져오기
info = medmnist.INFO[DATASET_NAME]

# 데이터세트 가져오기
prepared_dataset = download_and_prepare_dataset(info)
(train_videos, train_labels) = prepared_dataset[0]
(valid_videos, valid_labels) = prepared_dataset[1]
(test_videos, test_labels) = prepared_dataset[2]
# Out:
# Downloading data from https://zenodo.org/record/6496656/files/organmnist3d.npz?download=1
# 32661504/32657407 [==============================] - 72s 2us/step
# 32669696/32657407 [==============================] - 72s 2us/step

# %% [markdown]
# ## 05. tf.data pipeline 설계

# %%
@tf.function
def preprocess(frames: tf.Tensor, label: tf.Tensor):
    frames = tf.image.convert_image_dtype(
        frames[
            ..., tf.newaxis
        ],  # The new axis is to help for further processing with Conv3D layers
        tf.float32,
    )

    label = tf.cast(label, tf.float32)
    return frames, label


def prepare_dataloader(
    videos: np.ndarray,
    labels: np.ndarray,
    loader_type: str = "train",
    batch_size: int = BATCH_SIZE,
):
    dataset = tf.data.Dataset.from_tensor_slices((videos, labels))

    if loader_type == "train":
        dataset = dataset.shuffle(BATCH_SIZE * 2)

    dataloader = (
        dataset.map(preprocess, num_parallel_calls=tf.data.AUTOTUNE)
        .batch(batch_size)
        .prefetch(tf.data.AUTOTUNE)
    )
    return dataloader

# %%
# trainloader, vaildloader, testloader 정의
trainloader = prepare_dataloader(train_videos, train_labels, "train")
validloader = prepare_dataloader(valid_videos, valid_labels, "valid")
testloader = prepare_dataloader(test_videos, test_labels, "test")

# %% [markdown]
# ## 06. Tubelet Embedding

# %%
class TubeletEmbedding(layers.Layer):
    def __init__(self, embed_dim, patch_size, **kwargs):
        super().__init__(**kwargs)
        self.projection = layers.Conv3D(
            filters=embed_dim,
            kernel_size=patch_size,
            strides=patch_size,
            padding="VALID",
        )
        self.flatten = layers.Reshape(target_shape=(-1, embed_dim))

    def call(self, videos):
        projected_patches = self.projection(videos)
        flattened_patches = self.flatten(projected_patches)
        return flattened_patches

# %% [markdown]
# ## 07. Positional Embedding

# %%
class PositionalEncoder(layers.Layer):
    def __init__(self, embed_dim, **kwargs):
        super().__init__(**kwargs)
        self.embed_dim = embed_dim

    def build(self, input_shape):
        _, num_tokens, _ = input_shape
        self.position_embedding = layers.Embedding(
            input_dim=num_tokens, output_dim=self.embed_dim
        )
        self.positions = tf.range(start=0, limit=num_tokens, delta=1)

    def call(self, encoded_tokens):
        # Encode the positions and add it to the encoded tokens
        encoded_positions = self.position_embedding(self.positions)
        encoded_tokens = encoded_tokens + encoded_positions
        return encoded_tokens

# %% [markdown]
# ## 08. Video Vision Transformer

# %%
def create_vivit_classifier(
    tubelet_embedder,
    positional_encoder,
    input_shape=INPUT_SHAPE,
    transformer_layers=NUM_LAYERS,
    num_heads=NUM_HEADS,
    embed_dim=PROJECTION_DIM,
    layer_norm_eps=LAYER_NORM_EPS,
    num_classes=NUM_CLASSES,
):
    # input layer
    inputs = layers.Input(shape=input_shape)
    # patches 생성
    patches = tubelet_embedder(inputs)
    # patches 인코딩
    encoded_patches = positional_encoder(patches)

    # 다중 레이어 생성
    for _ in range(transformer_layers):
        # Layer normalization and MHSA
        x1 = layers.LayerNormalization(epsilon=1e-6)(encoded_patches)
        attention_output = layers.MultiHeadAttention(
            num_heads=num_heads, key_dim=embed_dim // num_heads, dropout=0.1
        )(x1, x1)

        x2 = layers.Add()([attention_output, encoded_patches])

        x3 = layers.LayerNormalization(epsilon=1e-6)(x2)
        x3 = keras.Sequential(
            [
                layers.Dense(units=embed_dim * 4, activation=tf.nn.gelu),
                layers.Dense(units=embed_dim, activation=tf.nn.gelu),
            ]
        )(x3)

        encoded_patches = layers.Add()([x3, x2])

    representation = layers.LayerNormalization(epsilon=layer_norm_eps)(encoded_patches)
    representation = layers.GlobalAvgPool1D()(representation)

    outputs = layers.Dense(units=num_classes, activation="softmax")(representation)

    # 모델 생성
    model = keras.Model(inputs=inputs, outputs=outputs)
    return model

# %% [markdown]
# ## 09. 모델 훈련

# %%
def run_experiment():
    # 모델 초기화
    model = create_vivit_classifier(
        tubelet_embedder=TubeletEmbedding(
            embed_dim=PROJECTION_DIM, patch_size=PATCH_SIZE
        ),
        positional_encoder=PositionalEncoder(embed_dim=PROJECTION_DIM),
    )

    # 옵티마이저, 손실함수, 매트릭스를 통한 모델 컴파일
    optimizer = keras.optimizers.Adam(learning_rate=LEARNING_RATE)
    model.compile(
        optimizer=optimizer,
        loss="sparse_categorical_crossentropy",
        metrics=[
            keras.metrics.SparseCategoricalAccuracy(name="accuracy"),
            keras.metrics.SparseTopKCategoricalAccuracy(5, name="top-5-accuracy"),
        ],
    )

    # 모델 훈련
    _ = model.fit(trainloader, epochs=EPOCHS, validation_data=validloader)

    _, accuracy, top_5_accuracy = model.evaluate(testloader)
    print(f"Test accuracy: {round(accuracy * 100, 2)}%")
    print(f"Test top 5 accuracy: {round(top_5_accuracy * 100, 2)}%")

    return model


model = run_experiment()
# Out:
# Epoch 1/60
# 31/31 [==============================] - 24s 422ms/step - loss: 2.4100 - accuracy: 0.1307 - top-5-accuracy: 0.6111 - val_loss: 2.2180 - val_accuracy: 0.2422 - val_top-5-accuracy: 0.7081
# Epoch 2/60
# 31/31 [==============================] - 12s 384ms/step - loss: 2.0878 - accuracy: 0.2058 - top-5-accuracy: 0.7531 - val_loss: 1.9416 - val_accuracy: 0.2298 - val_top-5-accuracy: 0.7391
# Epoch 3/60
# 31/31 [==============================] - 12s 386ms/step - loss: 1.9232 - accuracy: 0.2500 - top-5-accuracy: 0.8282 - val_loss: 1.7017 - val_accuracy: 0.3168 - val_top-5-accuracy: 0.8696
# Epoch 4/60
# 31/31 [==============================] - 12s 381ms/step - loss: 1.7617 - accuracy: 0.2932 - top-5-accuracy: 0.8786 - val_loss: 1.5232 - val_accuracy: 0.3416 - val_top-5-accuracy: 0.9379
# Epoch 5/60
# 31/31 [==============================] - 12s 399ms/step - loss: 1.6091 - accuracy: 0.3467 - top-5-accuracy: 0.9043 - val_loss: 1.4992 - val_accuracy: 0.3168 - val_top-5-accuracy: 0.9503
# Epoch 6/60
# 31/31 [==============================] - 12s 379ms/step - loss: 1.4432 - accuracy: 0.4393 - top-5-accuracy: 0.9239 - val_loss: 1.2170 - val_accuracy: 0.4720 - val_top-5-accuracy: 0.9565
# Epoch 7/60
# 31/31 [==============================] - 12s 384ms/step - loss: 1.3383 - accuracy: 0.4805 - top-5-accuracy: 0.9414 - val_loss: 1.1929 - val_accuracy: 0.4969 - val_top-5-accuracy: 0.9752
# Epoch 8/60
# 31/31 [==============================] - 12s 383ms/step - loss: 1.3102 - accuracy: 0.4722 - top-5-accuracy: 0.9465 - val_loss: 1.0678 - val_accuracy: 0.5652 - val_top-5-accuracy: 0.9752
# Epoch 9/60
# 31/31 [==============================] - 13s 420ms/step - loss: 1.2364 - accuracy: 0.5185 - top-5-accuracy: 0.9496 - val_loss: 0.9949 - val_accuracy: 0.5714 - val_top-5-accuracy: 0.9814
# Epoch 10/60
# 31/31 [==============================] - 12s 381ms/step - loss: 1.2058 - accuracy: 0.5278 - top-5-accuracy: 0.9527 - val_loss: 0.8689 - val_accuracy: 0.6832 - val_top-5-accuracy: 0.9876
# Epoch 11/60
# 31/31 [==============================] - 12s 382ms/step - loss: 1.0700 - accuracy: 0.5813 - top-5-accuracy: 0.9619 - val_loss: 0.7665 - val_accuracy: 0.7391 - val_top-5-accuracy: 0.9938
# Epoch 12/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.9877 - accuracy: 0.6183 - top-5-accuracy: 0.9691 - val_loss: 0.7561 - val_accuracy: 0.6708 - val_top-5-accuracy: 1.0000
# Epoch 13/60
# 31/31 [==============================] - 12s 381ms/step - loss: 0.9471 - accuracy: 0.6440 - top-5-accuracy: 0.9784 - val_loss: 0.8702 - val_accuracy: 0.6832 - val_top-5-accuracy: 0.9752
# Epoch 14/60
# 31/31 [==============================] - 12s 377ms/step - loss: 0.9140 - accuracy: 0.6348 - top-5-accuracy: 0.9815 - val_loss: 0.7462 - val_accuracy: 0.7329 - val_top-5-accuracy: 0.9938
# Epoch 15/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.8060 - accuracy: 0.6903 - top-5-accuracy: 0.9846 - val_loss: 0.6560 - val_accuracy: 0.7453 - val_top-5-accuracy: 1.0000
# Epoch 16/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.7669 - accuracy: 0.7315 - top-5-accuracy: 0.9856 - val_loss: 0.4809 - val_accuracy: 0.8634 - val_top-5-accuracy: 0.9938
# Epoch 17/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.6272 - accuracy: 0.7840 - top-5-accuracy: 0.9897 - val_loss: 0.5235 - val_accuracy: 0.8199 - val_top-5-accuracy: 1.0000
# Epoch 18/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.5904 - accuracy: 0.8076 - top-5-accuracy: 0.9938 - val_loss: 0.5101 - val_accuracy: 0.8385 - val_top-5-accuracy: 1.0000
# Epoch 19/60
# 31/31 [==============================] - 12s 402ms/step - loss: 0.5864 - accuracy: 0.7778 - top-5-accuracy: 0.9959 - val_loss: 0.5114 - val_accuracy: 0.8261 - val_top-5-accuracy: 1.0000
# Epoch 20/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.6273 - accuracy: 0.7819 - top-5-accuracy: 0.9846 - val_loss: 0.5055 - val_accuracy: 0.8509 - val_top-5-accuracy: 1.0000
# Epoch 21/60
# 31/31 [==============================] - 12s 377ms/step - loss: 0.4806 - accuracy: 0.8374 - top-5-accuracy: 0.9918 - val_loss: 0.3943 - val_accuracy: 0.8944 - val_top-5-accuracy: 0.9938
# Epoch 22/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.3801 - accuracy: 0.8704 - top-5-accuracy: 0.9959 - val_loss: 0.4661 - val_accuracy: 0.8634 - val_top-5-accuracy: 1.0000
# Epoch 23/60
# 31/31 [==============================] - 12s 378ms/step - loss: 0.3685 - accuracy: 0.8693 - top-5-accuracy: 0.9979 - val_loss: 0.3805 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 24/60
# 31/31 [==============================] - 12s 387ms/step - loss: 0.3833 - accuracy: 0.8611 - top-5-accuracy: 0.9990 - val_loss: 0.3610 - val_accuracy: 0.8634 - val_top-5-accuracy: 0.9938
# Epoch 25/60
# 31/31 [==============================] - 12s 375ms/step - loss: 0.3050 - accuracy: 0.8981 - top-5-accuracy: 0.9990 - val_loss: 0.4150 - val_accuracy: 0.9006 - val_top-5-accuracy: 0.9938
# Epoch 26/60
# 31/31 [==============================] - 12s 378ms/step - loss: 0.2785 - accuracy: 0.9023 - top-5-accuracy: 0.9979 - val_loss: 0.3222 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 27/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.2503 - accuracy: 0.9105 - top-5-accuracy: 0.9990 - val_loss: 0.2723 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 28/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.2369 - accuracy: 0.9228 - top-5-accuracy: 1.0000 - val_loss: 0.2788 - val_accuracy: 0.9130 - val_top-5-accuracy: 1.0000
# Epoch 29/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.2281 - accuracy: 0.9249 - top-5-accuracy: 1.0000 - val_loss: 0.2852 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 30/60
# 31/31 [==============================] - 13s 409ms/step - loss: 0.1884 - accuracy: 0.9331 - top-5-accuracy: 1.0000 - val_loss: 0.2705 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 31/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.1570 - accuracy: 0.9568 - top-5-accuracy: 1.0000 - val_loss: 0.2678 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 32/60
# 31/31 [==============================] - 12s 378ms/step - loss: 0.1644 - accuracy: 0.9506 - top-5-accuracy: 1.0000 - val_loss: 0.3684 - val_accuracy: 0.8758 - val_top-5-accuracy: 1.0000
# Epoch 33/60
# 31/31 [==============================] - 12s 383ms/step - loss: 0.1391 - accuracy: 0.9496 - top-5-accuracy: 1.0000 - val_loss: 0.3338 - val_accuracy: 0.9130 - val_top-5-accuracy: 1.0000
# Epoch 34/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.0992 - accuracy: 0.9753 - top-5-accuracy: 1.0000 - val_loss: 0.3533 - val_accuracy: 0.8944 - val_top-5-accuracy: 1.0000
# Epoch 35/60
# 31/31 [==============================] - 12s 377ms/step - loss: 0.1141 - accuracy: 0.9599 - top-5-accuracy: 1.0000 - val_loss: 0.4539 - val_accuracy: 0.8820 - val_top-5-accuracy: 1.0000
# Epoch 36/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.0780 - accuracy: 0.9774 - top-5-accuracy: 1.0000 - val_loss: 0.3740 - val_accuracy: 0.9068 - val_top-5-accuracy: 1.0000
# Epoch 37/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.0611 - accuracy: 0.9815 - top-5-accuracy: 1.0000 - val_loss: 0.3456 - val_accuracy: 0.8820 - val_top-5-accuracy: 1.0000
# Epoch 38/60
# 31/31 [==============================] - 12s 378ms/step - loss: 0.0508 - accuracy: 0.9897 - top-5-accuracy: 1.0000 - val_loss: 0.2602 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 39/60
# 31/31 [==============================] - 12s 381ms/step - loss: 0.0370 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.2902 - val_accuracy: 0.9379 - val_top-5-accuracy: 1.0000
# Epoch 40/60
# 31/31 [==============================] - 12s 383ms/step - loss: 0.0358 - accuracy: 0.9918 - top-5-accuracy: 1.0000 - val_loss: 0.4488 - val_accuracy: 0.9068 - val_top-5-accuracy: 0.9938
# Epoch 41/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.1318 - accuracy: 0.9516 - top-5-accuracy: 1.0000 - val_loss: 0.4618 - val_accuracy: 0.8882 - val_top-5-accuracy: 0.9938
# Epoch 42/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.1394 - accuracy: 0.9568 - top-5-accuracy: 0.9979 - val_loss: 0.4506 - val_accuracy: 0.8882 - val_top-5-accuracy: 1.0000
# Epoch 43/60
# 31/31 [==============================] - 12s 377ms/step - loss: 0.0686 - accuracy: 0.9846 - top-5-accuracy: 1.0000 - val_loss: 0.2990 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 44/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.0243 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.2667 - val_accuracy: 0.8944 - val_top-5-accuracy: 1.0000
# Epoch 45/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.0255 - accuracy: 0.9969 - top-5-accuracy: 1.0000 - val_loss: 0.3977 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 46/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.0423 - accuracy: 0.9897 - top-5-accuracy: 1.0000 - val_loss: 0.4251 - val_accuracy: 0.8882 - val_top-5-accuracy: 1.0000
# Epoch 47/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.0662 - accuracy: 0.9784 - top-5-accuracy: 1.0000 - val_loss: 0.3411 - val_accuracy: 0.9006 - val_top-5-accuracy: 1.0000
# Epoch 48/60
# 31/31 [==============================] - 12s 380ms/step - loss: 0.1683 - accuracy: 0.9444 - top-5-accuracy: 1.0000 - val_loss: 0.5684 - val_accuracy: 0.8447 - val_top-5-accuracy: 1.0000
# Epoch 49/60
# 31/31 [==============================] - 12s 377ms/step - loss: 0.0749 - accuracy: 0.9784 - top-5-accuracy: 1.0000 - val_loss: 0.2834 - val_accuracy: 0.9317 - val_top-5-accuracy: 1.0000
# Epoch 50/60
# 31/31 [==============================] - 12s 376ms/step - loss: 0.0270 - accuracy: 0.9938 - top-5-accuracy: 1.0000 - val_loss: 0.2350 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 51/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.0118 - accuracy: 0.9990 - top-5-accuracy: 1.0000 - val_loss: 0.2440 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 52/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.0061 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2514 - val_accuracy: 0.9317 - val_top-5-accuracy: 1.0000
# Epoch 53/60
# 31/31 [==============================] - 12s 390ms/step - loss: 0.0045 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2450 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 54/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.0035 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2363 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 55/60
# 31/31 [==============================] - 12s 381ms/step - loss: 0.0026 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2385 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 56/60
# 31/31 [==============================] - 12s 382ms/step - loss: 0.0025 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2404 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 57/60
# 31/31 [==============================] - 12s 381ms/step - loss: 0.0023 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2416 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 58/60
# 31/31 [==============================] - 12s 383ms/step - loss: 0.0022 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2324 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# Epoch 59/60
# 31/31 [==============================] - 12s 379ms/step - loss: 0.0018 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2415 - val_accuracy: 0.9193 - val_top-5-accuracy: 1.0000
# Epoch 60/60
# 31/31 [==============================] - 13s 419ms/step - loss: 0.0018 - accuracy: 1.0000 - top-5-accuracy: 1.0000 - val_loss: 0.2418 - val_accuracy: 0.9255 - val_top-5-accuracy: 1.0000
# 20/20 [==============================] - 2s 119ms/step - loss: 0.9464 - accuracy: 0.7934 - top-5-accuracy: 0.9820
# Test accuracy: 79.34%
# Test top 5 accuracy: 98.2%

# %% [markdown]
# ## 10. 추론

# %%
NUM_SAMPLES_VIZ = 25
testsamples, labels = next(iter(testloader))
testsamples, labels = testsamples[:NUM_SAMPLES_VIZ], labels[:NUM_SAMPLES_VIZ]

ground_truths = []
preds = []
videos = []

for i, (testsample, label) in enumerate(zip(testsamples, labels)):
    # gif 생성
    with io.BytesIO() as gif:
        imageio.mimsave(gif, (testsample.numpy() * 255).astype("uint8"), "GIF", fps=5)
        videos.append(gif.getvalue())

    # 모델 예측
    output = model.predict(tf.expand_dims(testsample, axis=0))[0]
    pred = np.argmax(output, axis=0)

    ground_truths.append(label.numpy().astype("int"))
    preds.append(pred)

# %%
def make_box_for_grid(image_widget, fit):
    # 캡션 생성
    if fit is not None:
        fit_str = "'{}'".format(fit)
    else:
        fit_str = str(fit)

    h = ipywidgets.HTML(value="" + str(fit_str) + "")

    boxb = ipywidgets.widgets.Box()
    boxb.children = [image_widget]

    vb = ipywidgets.widgets.VBox()
    vb.layout.align_items = "center"
    vb.children = [h, boxb]
    return vb

# %%
# 캡션 붙인 gif video 시각화
boxes = []
for i in range(NUM_SAMPLES_VIZ):
    ib = ipywidgets.widgets.Image(value=videos[i], width=100, height=100)
    true_class = info["label"][str(ground_truths[i])]
    pred_class = info["label"][str(preds[i])]
    caption = f"T: {true_class} | P: {pred_class}"

    boxes.append(make_box_for_grid(ib, caption))

ipywidgets.widgets.GridBox(
    boxes, layout=ipywidgets.widgets.Layout(grid_template_columns="repeat(5, 200px)")
)
# Out:
# GridBox(children=(VBox(children=(HTML(value="'T: pancreas | P: pancreas'"), Box(children=(Image(value=b'GIF89a…
