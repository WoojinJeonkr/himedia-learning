# %%
# %matplotlib
# IPython 셀이나 주피터 노트북과 matplotlib 통합을 설정
# 만약 이 기능을 실행하지 않으면
# 노트북의 경우 그래프가 화면에 나타나지 않거나
# 셀의 경우 세션의 제어권을 뺏기게 된다
# IPython 셀에서 %matplotlib을 실행하면 콘솔 세션을 방해받지 않고
# 여러 플롯 윈도우가 생성 가능하다

# %%
# %matplotlib
# Out:
# Using matplotlib backend: Qt5Agg

# %%
# %matplotlib inline

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
plt.plot(np.random.randn(50).cumsum())
